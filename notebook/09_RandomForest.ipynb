# %%
import pandas as pd

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    roc_auc_score
)

import matplotlib.pyplot as plt

# %%
X_train = pd.read_csv("../data/X_train.csv")
X_test = pd.read_csv("../data/X_test.csv")

y_train = pd.read_csv("../data/y_train.csv").squeeze()
y_test = pd.read_csv("../data/y_test.csv").squeeze()

# %%
rf = RandomForestClassifier(
    random_state=42
)

# %%
rf.fit(
    X_train,
    y_train
)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf.predict(
    X_test
)

y_prob = rf.predict_proba(
    X_test
)[:,1]

# %%
print("="*50)

print("Accuracy")

print(
    accuracy_score(
        y_test,
        y_pred
    )
)
# Out:
# ==================================================
# Accuracy
# 0.85

# %%
print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        60
#            1       0.85      1.00      0.92       340
#
#     accuracy                           0.85       400
#    macro avg       0.42      0.50      0.46       400
# weighted avg       0.72      0.85      0.78       400
# d:\AI\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\AI\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# d:\AI\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
cm = confusion_matrix(
    y_test,
    y_pred
)

print(cm)
# Out:
# [[  0  60]
#  [  0 340]]

# %%
auc = roc_auc_score(
    y_test,
    y_prob
)

print("AUC")

print(auc)
# Out:
# AUC
# 0.513186274509804

# %%
importance = pd.DataFrame({

    "Feature":X_train.columns,

    "Importance":rf.feature_importances_

})

importance = importance.sort_values(

    "Importance",

    ascending=False
)

importance.head(20)
# Out:
#                            Feature  Importance
# 1                      CreditScore    0.062932
# 2                    MonthlyIncome    0.062652
# 0                              Age    0.053456
# 7                       SessionDay    0.052782
# 6                      SessionHour    0.049146
# 9                      TotalAmount    0.048366
# 8                     SessionMonth    0.044786
# 5                         Quantity    0.034236
# 4                            Price    0.029215
# 3                             Cost    0.028393
# 10                          Profit    0.025044
# 118        CampaignSchema _E-mails    0.013176
# 11                   Gender_Female    0.011542
# 12                     Gender_Male    0.011535
# 128                Weekday_Tuesday    0.010943
# 121  CampaignSchema _Instagram-ads    0.010693
# 120     CampaignSchema _Google-ads    0.009692
# 124                 Weekday_Monday    0.009645
# 125               Weekday_Saturday    0.009628
# 122    CampaignSchema _Twitter-ads    0.009006

# %%
top20 = importance.head(20)

plt.figure(figsize=(8,8))

plt.barh(
    top20["Feature"],
    top20["Importance"]
)

plt.gca().invert_yaxis()

plt.show()

# %%
train_acc = rf.score(
    X_train,
    y_train
)

test_acc = rf.score(
    X_test,
    y_test
)

print("Train:", train_acc)

print("Test :", test_acc)
# Out:
# Train: 0.999375
# Test : 0.85

# %%
rf2 = RandomForestClassifier(

    n_estimators=300,

    random_state=42

)

rf2.fit(
    X_train,
    y_train
)
# Out:
# RandomForestClassifier(n_estimators=300, random_state=42)

# %%
rf3 = RandomForestClassifier(

    n_estimators=200,

    max_depth=10,

    random_state=42

)

rf3.fit(
    X_train,
    y_train
)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=200, random_state=42)
